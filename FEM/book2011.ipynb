# %% [markdown]
# 2011-Second-order characteristic schemes in time and age for a nonlinear age-structured population model 复现

# %%
import numpy as np
import math

def read_mesh_date():

    pass

def print_mesh_info():

    pass

def basic_functions():

    pass

def build_stiffness_matrix():

    pass

def build_mass_matrix():
    
    pass

def build_reaction_matrix():

    pass
